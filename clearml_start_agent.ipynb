# %%
# !pip install git+https://github.com/clearml/clearml
# !pip install clearml-agent
# Out:
# ...
#   Cloning https://github.com/clearml/clearml to /tmp/pip-req-build-tkwyyxdr
#   Running command git clone --filter=blob:none --quiet https://github.com/clearml/clearml /tmp/pip-req-build-tkwyyxdr
#   Resolved https://github.com/clearml/clearml to commit 804ecae2dc762335438f88eb73f72b67c3af73b8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# ...
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# ...

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2026-04-25 04:57:35.207116

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=6C33RZP2NG3LO3C2KT7KTHQ4GQXOFP
# %env CLEARML_API_SECRET_KEY=Y1reoT0UiEZxhjyfnUN2dbsiBNMkPpqa2kdUp_5kKmziYiPZlRFdMd0ehuoulb4C9Lc
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=6C33RZP2NG3LO3C2KT7KTHQ4GQXOFP
# env: CLEARML_API_SECRET_KEY=Y1reoT0UiEZxhjyfnUN2dbsiBNMkPpqa2kdUp_5kKmziYiPZlRFdMd0ehuoulb4C9Lc

# %%
# !clearml-agent daemon --queue Deepfilter
# Out:
# /opt/conda/lib/python3.12/site-packages/clearml_agent/external/requirements_parser/requirement.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req
# Using environment access key CLEARML_API_ACCESS_KEY=6C33RZP2NG3LO3C2KT7KTHQ4GQXOFP
# Using environment secret key CLEARML_API_SECRET_KEY=********
#
# clearml_agent: ERROR: Could not find queue with name/id "Deepfilter"

# %%
# Create a new script for the following command

# !clearml-agent daemon --queue default  --stop
print("Command completed")
# Out:
# /opt/conda/lib/python3.12/site-packages/clearml_agent/external/requirements_parser/requirement.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement as Req
# Using environment access key CLEARML_API_ACCESS_KEY=6C33RZP2NG3LO3C2KT7KTHQ4GQXOFP
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Could not find a running clearml-agent instance with worker_name=default worker_id=default:gpuall
# Command completed
