# %%
from clearml import Task
Task.set_credentials(
     api_host="https://api.clear.ml",
     web_host="https://app.clear.ml",
     files_host="https://files.clear.ml",
     key='X7HW4KVENA2D71JXWCI4USFNLME8ZW',
     secret='adRdKR2Y7-5f0feh37Ad6vECZvUWwfdi-sVw1QRYDn4j8sunIgcJLq7c83j2H7IQst8'
)
# Out:
# /Users/Ziyi/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# !clearml-agent daemon --queue pipeline  --stop
# Out:
# Using environment access key CLEARML_API_ACCESS_KEY=X7HW4KVENA2D71JXWCI4USFNLME8ZW
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Could not find a running clearml-agent instance with worker_name=brendvidafoxmailcomdeMacBook-Pro-2.local worker_id=clearml-agent-mbp-c
