# %% [markdown]
# #  ClearML Pipeline Demo
#
# This notebook demonstrates how to build and run a **task-based pipeline** using [ClearML](https://clear.ml), including:
#
# - Upload dataset artifact
# - Preprocess data
# - Train a model
# - Run a full pipeline

# %% [markdown]
# ## Step 0: Initialize ClearML in SageMaker (via Terminal)
#
# 1. Open **Terminal** in JupyterLab
#
# 2. Install ClearML:
#
# ```bash
# pip install -U clearml clearml-agent
# ```
#
# 3. Run initialization:
#
# ```bash
# clearml-init
# ```
#
# 4. Follow prompts:
#
# - Go to: https://app.clear.ml/settings/workspace-configuration
# - Click **Create new credentials**
# - Copy the configuration
# - Paste into terminal when prompted
#
# 5. After completion, config will be saved to:
#
# ```bash
# ~/.clearml.conf
# ```

# %% [markdown]
# ##  Step 1: Upload Dataset as Artifact

# %%
# !python s1_dataset_artifact.py
# Out:
# ClearML Task: created new task id=8abf6fb039cf4d9b98e5d686df39efd0
# 2026-04-02 06:50:42.677192: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-02 06:50:42.840763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775112642.870166    7173 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775112642.881215    7173 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-02 06:50:43.068442: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/a1df0547583b4bdbb5edd81134f6cc50/experiments/8abf6fb039cf4d9b98e5d686df39efd0/output/log
# 2026-04-02 06:50:49,948 - clearml.Task - INFO - Waiting for repository detection and full package requirement analysis
# 2026-04-02 06:50:57,834 - clearml.Task - INFO - Finished repository detection and package analysis
# ClearML Terminating local execution process - continuing execution remotely

# %% [markdown]
# ## Step 2: Preprocess Dataset

# %%
# !python s2_data_preprocessing.py
# Out:
# ClearML Task: created new task id=ff4c4af416a54ac6944f672c0ba106dc
# 2026-04-02 06:51:57.290302: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-02 06:51:57.303951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775112717.321541    7257 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775112717.326939    7257 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-02 06:51:57.343726: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/a1df0547583b4bdbb5edd81134f6cc50/experiments/ff4c4af416a54ac6944f672c0ba106dc/output/log
# Arguments: {'dataset_task_id': '', 'random_state': 42, 'test_size': 0.2}
# 2026-04-02 06:52:04,261 - clearml.Task - INFO - Waiting for repository detection and full package requirement analysis
# 2026-04-02 06:52:08,918 - clearml.Task - INFO - Finished repository detection and package analysis
# ClearML Terminating local execution process - continuing execution remotely

# %% [markdown]
# ##  Step 3: Train Model

# %%
# !python s3_train_model.py
# Out:
# ClearML Task: created new task id=b6cfe8806a63423c9a5d022e7777ea8c
# 2026-04-02 06:52:49.734538: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-02 06:52:49.747826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775112769.765669    7393 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775112769.771081    7393 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-02 06:52:49.788061: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/a1df0547583b4bdbb5edd81134f6cc50/experiments/b6cfe8806a63423c9a5d022e7777ea8c/output/log
# 2026-04-02 06:52:58,330 - clearml.Task - INFO - Waiting for repository detection and full package requirement analysis
# 2026-04-02 06:53:01,799 - clearml.Task - INFO - Finished repository detection and package analysis
# ClearML Terminating local execution process - continuing execution remotely

# %% [markdown]
# ##  Set up ClearML Agent & Queue

# %% [markdown]
# # Start the agent from terminal:
# clearml-agent daemon --queue tasks --detached
#
# CLEARML_WORKER_ID=pipeline_controller clearml-agent daemon --queue pipeline_controller --detache

# %% [markdown]
# ##  Run the Pipeline

# %%
# !python main.py
# Out:
# Hi, AI Studio
# ClearML Task: created new task id=8c4e13797ef445b996acfcfa4b55cf26
# 2026-04-02 07:11:56.361330: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-02 07:11:56.539483: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775113916.571482    8578 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775113916.583656    8578 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-02 07:11:56.784854: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/9f3cdbcd42314feb8c9d14106cf49336/experiments/8c4e13797ef445b996acfcfa4b55cf26/output/log
# ClearML pipeline page: https://app.clear.ml/pipelines/9f3cdbcd42314feb8c9d14106cf49336/experiments/8c4e13797ef445b996acfcfa4b55cf26
# Switching to remote execution, output log page https://app.clear.ml/projects/9f3cdbcd42314feb8c9d14106cf49336/experiments/8c4e13797ef445b996acfcfa4b55cf26/output/log
# ClearML Terminating local execution process - continuing execution remotely

# %% [markdown]
# ##  Shutdown the queue
# clearml-agent daemon --queue tasks --stop
#
# CLEARML_WORKER_ID=pipeline_controller clearml-agent daemon --queue pipeline_controller --stop

# %% [markdown]
# ##  References
#
# - [ClearML Documentation](https://clear.ml/docs)
# - [ClearML Pipelines Guide](https://clear.ml/docs/latest/docs/getting_started/building_pipelines)
# - [ClearML GitHub](https://github.com/allegroai/clearml)
